# %%
import my_grover as projekt

# %%
# %%writefile clauses_small.txt
# 0,1
# 0,2
# 1,3
# 2,3
# Out:
# Writing clauses_small.txt

# %%
path = "clauses_small.txt"
graph_file ="graph_file_small"
counts = projekt.Grovers(path,10000)
projekt.my_plot(counts,graph_file)

# %%
# %%writefile clauses_large.txt
# 0,1
# 0,2
# 1,3
# 2,3
# 4,5
# 4,6
# 5,7
# 6,7
# Out:
# Writing clauses_large.txt

# %%
path = "clauses_large.txt"
graph_file ="graph_file_large"
counts = projekt.Grovers(path,10000)
projekt.my_plot(counts,graph_file)
print(counts)
# Out:
# {'11000011': 19, '11001111': 33, '11001011': 26, '00011100': 24, '01001011': 24, '10000100': 24, '00101010': 29, '00111101': 16, '01111010': 18, '10101100': 25, '01100010': 20, '01000111': 41, '00011000': 26, '01100100': 22, '01011001': 27, '01111110': 20, '01010001': 39, '01001100': 15, '11010111': 22, '00000011': 12, '00110101': 24, '10101101': 24, '01000100': 15, '01011100': 33, '01010011': 34, '00010010': 26, '00010001': 24, '11000100': 28, '11011110': 32, '00110111': 21, '10010111': 31, '10111010': 30, '00110110': 27, '11111101': 26, '10001011': 18, '00101011': 21, '01001111': 18, '01101111': 30, '01110011': 20, '11000001': 27, '11100111': 28, '10001111': 21, '00000101': 19, '01110111': 26, '00001100': 32, '11011010': 26, '10011110': 23, '10001100': 28, '00000100': 23, '11011100': 30, '11001110': 26, '01010110': 34, '10011011': 26, '10111011': 27, '11101010': 20, '11101101': 30, '11110000': 18, '11101100': 19, '11011101': 31, '10110000': 27, '11010011': 21, '11000000': 29, '1100
# ...
